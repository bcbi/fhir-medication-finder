# %%
! pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: blinker==1.6.2 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: certifi==2023.7.22 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.2.0 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: click==8.1.7 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: Flask==2.3.3 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: idna==3.4 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: importlib-metadata==6.8.0 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 7)) (6.8.0)
# Requirement already satisfied: itsdangerous==2.1.2 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: Jinja2==3.1.2 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: MarkupSafe==2.1.3 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 10)) (2.1.3)
# Requirement already satisfied: python-dotenv==1.0.0 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: requests==2.31.0 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: urllib3==2.0.5 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 13)) (2.0.5)
# Requirement already satisfied: Werkzeug==2.3.7 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 14)) (2.3.7)
# Requirement already satisfied: zipp==3.17.0 in /Users/mounikathakkallapally/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 15)) (3.17.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import requests
import os
from flask import Flask, request, render_template
from dotenv import load_dotenv

# %%
s = requests.Session()

# %%
patient_id = 1

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")


credentials = (username, password)

r = s.get("http://pwebmedcit.services.brown.edu:8081/fhir" + f"/MedicationRequest?patient={patient_id}", auth=credentials)
r
# Out:
# <Response [200]>

# %%
patient = s.get(f"http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest?patient={patient_id}", headers = {'Accept': 'application/fhir/json'}, auth=credentials) 
patient
# Out:
# <Response [200]>

# %%
patient_json = patient.json()
patient_json
# Out:
# {'resourceType': 'Bundle',
#  'id': '7a398cd0-5007-48eb-90eb-0cdda7ab4af1',
#  'meta': {'lastUpdated': '2023-12-07T19:52:32.138+00:00'},
#  'type': 'searchset',
#  'total': 19,
#  'link': [{'relation': 'self',
#    'url': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest?patient=1'}],
#  'entry': [{'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/1',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '1',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '282464',
#        'display': 'acetaminophen 160 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1958-03-11T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 90,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/2',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '2',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '243670',
#        'display': 'aspirin 81 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1970-12-03T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 28,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/3',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '3',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '834061',
#        'display': 'penicillin V potassium 250 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1953-02-06T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 10,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/4',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '4',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '562251',
#        'display': 'amoxicillin 250 MG / clavulanate 125 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1967-05-30T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 21,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/5',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '5',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '562251',
#        'display': 'amoxicillin 250 MG / clavulanate 125 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '2012-02-14T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 14,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/6',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '6',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '140587',
#        'display': 'celecoxib'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'encounter': {'reference': 'Encounter/85'},
#     'authoredOn': '1982-08-12T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/7',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '7',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '313782',
#        'display': 'acetaminophen 325 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1971-01-04T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 14,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/8',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '8',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '313782',
#        'display': 'acetaminophen 325 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1982-09-11T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 21,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/9',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '9',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '310965',
#        'display': 'ibuprofen 200 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1978-06-22T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 35,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/10',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '10',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '1049221',
#        'display': 'acetaminophen 325 MG / oxycodone hydrochloride 5 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1978-06-22T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/11',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '11',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '789980',
#        'display': 'ampicillin 100 MG/ML Injectable Solution'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1978-06-22T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 35,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/12',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '12',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '243670',
#        'display': 'aspirin 81 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1981-08-10T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 37,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/13',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '13',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '309362',
#        'display': 'clopidogrel 75 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '2006-03-09T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/14',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '14',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '705129',
#        'display': 'nitroglycerin 0.4 MG/ACTUAT Mucosal Spray'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '2006-03-09T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/15',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '15',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '197361',
#        'display': 'amlodipine 5 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '2006-03-09T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/16',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '16',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '312961',
#        'display': 'simvastatin 20 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '2006-03-09T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 0,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/17',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '17',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '313782',
#        'display': 'acetaminophen 325 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1976-10-20T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 14,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/18',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '18',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '313782',
#        'display': 'acetaminophen 325 MG Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1980-03-15T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 14,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/MedicationRequest/19',
#    'resource': {'resourceType': 'MedicationRequest',
#     'id': '19',
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '309043',
#        'display': '12 HR cefaclor 500 MG Extended Release Oral Tablet'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'ANTONY DORCELUS'},
#     'authoredOn': '1980-03-15T00:00:00+00:00',
#     'dispenseRequest': {'numberOfRepeatsAllowed': 0,
#      'quantity': {'value': 0.0},
#      'expectedSupplyDuration': {'value': 14,
#       'unit': 'day',
#       'system': 'http://unitsofmeasure.org',
#       'code': 'd'}}}}]}

# %%
patient_json.keys()
# Out:
# dict_keys(['resourceType', 'id', 'meta', 'type', 'total', 'link', 'entry'])

# %%
m = s.get("http://pwebmedcit.services.brown.edu:8081/fhir" + f"/Patient?patient={patient_id}", auth=credentials)
m
# Out:
# <Response [200]>

# %%
m_json = m.json()
m_json
# Out:
# {'resourceType': 'Bundle',
#  'id': '5bb4d62c-2cde-4f10-9be9-ec146acb04fa',
#  'meta': {'lastUpdated': '2023-12-07T21:20:49.819+00:00'},
#  'type': 'searchset',
#  'total': 2694,
#  'link': [{'relation': 'self',
#    'url': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient?patient=1'},
#   {'relation': 'next',
#    'url': 'http://pwebmedcit.services.brown.edu:8081/fhir?_getpages=9bdc8786-0f64-465a-a204-a022546fac30&_getpagesoffset=100&_count=100&_pretty=true&_bundletype=searchset'}],
#  'entry': [{'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/1',
#    'resource': {'resourceType': 'Patient',
#     'id': '1',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">ANTONY <b>DORCELUS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>000728a7-80de-420a-9286-2c20e81cb7b8</td></tr><tr><td>Date of birth</td><td><span>27 January 1949</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '000728a7-80de-420a-9286-2c20e81cb7b8'}],
#     'active': False,
#     'name': [{'family': 'DORCELUS', 'given': ['ANTONY']}],
#     'gender': 'male',
#     'birthDate': '1949-01-27'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/2',
#    'resource': {'resourceType': 'Patient',
#     'id': '2',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">LEOTA <b>PARAMO </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00093765-abef-4a56-9280-8f92422afae7</td></tr><tr><td>Date of birth</td><td><span>01 June 1920</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '00093765-abef-4a56-9280-8f92422afae7'}],
#     'active': False,
#     'name': [{'family': 'PARAMO', 'given': ['LEOTA']}],
#     'gender': 'female',
#     'birthDate': '1920-06-01'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/3',
#    'resource': {'resourceType': 'Patient',
#     'id': '3',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">PERRY <b>GASKAMP </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>000cb58f-523d-49a2-a05e-de1e93f35c01</td></tr><tr><td>Date of birth</td><td><span>03 January 1916</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '000cb58f-523d-49a2-a05e-de1e93f35c01'}],
#     'active': False,
#     'name': [{'family': 'GASKAMP', 'given': ['PERRY']}],
#     'gender': 'male',
#     'birthDate': '1916-01-03'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/5',
#    'resource': {'resourceType': 'Patient',
#     'id': '5',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">EMILIO <b>GUERARD </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00196a95-1567-41f8-b608-18e6295b4c1e</td></tr><tr><td>Date of birth</td><td><span>24 July 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}},
#        {'url': 'text', 'valueString': 'Asian'}]}],
#     'identifier': [{'value': '00196a95-1567-41f8-b608-18e6295b4c1e'}],
#     'active': False,
#     'name': [{'family': 'GUERARD', 'given': ['EMILIO']}],
#     'gender': 'male',
#     'birthDate': '1968-07-24'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/6',
#    'resource': {'resourceType': 'Patient',
#     'id': '6',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">CLARETTA <b>GANTEWOOD </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>001f4a87-70d0-435c-a4b9-1425f6928d33</td></tr><tr><td>Date of birth</td><td><span>31 December 1963</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '001f4a87-70d0-435c-a4b9-1425f6928d33'}],
#     'active': False,
#     'name': [{'family': 'GANTEWOOD', 'given': ['CLARETTA']}],
#     'gender': 'female',
#     'birthDate': '1963-12-31'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/7',
#    'resource': {'resourceType': 'Patient',
#     'id': '7',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">SALENA <b>HEIBERG </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00211cd2-f171-45d9-a7c6-ea8ac6d28d09</td></tr><tr><td>Date of birth</td><td><span>06 November 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '00211cd2-f171-45d9-a7c6-ea8ac6d28d09'}],
#     'active': False,
#     'name': [{'family': 'HEIBERG', 'given': ['SALENA']}],
#     'gender': 'female',
#     'birthDate': '1968-11-06'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/9',
#    'resource': {'resourceType': 'Patient',
#     'id': '9',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">IZOLA <b>SIEFFERMAN </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>002805e7-7624-4cb7-b68d-e8ac92f61ff9</td></tr><tr><td>Date of birth</td><td><span>20 July 1978</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '002805e7-7624-4cb7-b68d-e8ac92f61ff9'}],
#     'active': False,
#     'name': [{'family': 'SIEFFERMAN', 'given': ['IZOLA']}],
#     'gender': 'female',
#     'birthDate': '1978-07-20'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/11',
#    'resource': {'resourceType': 'Patient',
#     'id': '11',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">TRENT <b>RAMKISSOON </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0029df47-1263-4576-8ca3-4615adb7dd7a</td></tr><tr><td>Date of birth</td><td><span>03 February 1953</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0029df47-1263-4576-8ca3-4615adb7dd7a'}],
#     'active': False,
#     'name': [{'family': 'RAMKISSOON', 'given': ['TRENT']}],
#     'gender': 'male',
#     'birthDate': '1953-02-03'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/12',
#    'resource': {'resourceType': 'Patient',
#     'id': '12',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">HASSIE <b>FREEBURGER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0030eb48-316c-4250-907f-a272909ff8b9</td></tr><tr><td>Date of birth</td><td><span>30 January 1963</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0030eb48-316c-4250-907f-a272909ff8b9'}],
#     'active': False,
#     'name': [{'family': 'FREEBURGER', 'given': ['HASSIE']}],
#     'gender': 'female',
#     'birthDate': '1963-01-30'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/16',
#    'resource': {'resourceType': 'Patient',
#     'id': '16',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">SANDIE <b>DUKAS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00444703-f2c9-45c9-a247-f6317a43a929</td></tr><tr><td>Date of birth</td><td><span>13 October 1971</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '00444703-f2c9-45c9-a247-f6317a43a929'}],
#     'active': False,
#     'name': [{'family': 'DUKAS', 'given': ['SANDIE']}],
#     'gender': 'female',
#     'birthDate': '1971-10-13'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/17',
#    'resource': {'resourceType': 'Patient',
#     'id': '17',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MARGENE <b>GRESSMIRE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>005823a2-895f-4af4-afc8-81ab84059889</td></tr><tr><td>Date of birth</td><td><span>11 December 1950</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '005823a2-895f-4af4-afc8-81ab84059889'}],
#     'active': False,
#     'name': [{'family': 'GRESSMIRE', 'given': ['MARGENE']}],
#     'gender': 'female',
#     'birthDate': '1950-12-11'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/18',
#    'resource': {'resourceType': 'Patient',
#     'id': '18',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MAUD <b>TANEY </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0084b0fe-e30f-4930-b6d1-5e1eff4b7dea</td></tr><tr><td>Date of birth</td><td><span>17 November 1965</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0084b0fe-e30f-4930-b6d1-5e1eff4b7dea'}],
#     'active': False,
#     'name': [{'family': 'TANEY', 'given': ['MAUD']}],
#     'gender': 'female',
#     'birthDate': '1965-11-17'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/19',
#    'resource': {'resourceType': 'Patient',
#     'id': '19',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">UN <b>LICOR </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0088faee-d229-448d-adbb-e84ff92aba1c</td></tr><tr><td>Date of birth</td><td><span>30 January 1949</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '0088faee-d229-448d-adbb-e84ff92aba1c'}],
#     'active': False,
#     'name': [{'family': 'LICOR', 'given': ['UN']}],
#     'gender': 'female',
#     'birthDate': '1949-01-30'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/23',
#    'resource': {'resourceType': 'Patient',
#     'id': '23',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">FERMIN <b>ALEFF </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00badc72-67b3-41b8-82c3-781e775c026e</td></tr><tr><td>Date of birth</td><td><span>07 September 1978</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}},
#        {'url': 'text', 'valueString': 'Asian'}]}],
#     'identifier': [{'value': '00badc72-67b3-41b8-82c3-781e775c026e'}],
#     'active': False,
#     'name': [{'family': 'ALEFF', 'given': ['FERMIN']}],
#     'gender': 'male',
#     'birthDate': '1978-09-07'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/28',
#    'resource': {'resourceType': 'Patient',
#     'id': '28',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">OMAR <b>FARRAJ </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00fb4ef9-47c6-4e09-a095-effacf18d0bf</td></tr><tr><td>Date of birth</td><td><span>31 October 1979</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '00fb4ef9-47c6-4e09-a095-effacf18d0bf'}],
#     'active': False,
#     'name': [{'family': 'FARRAJ', 'given': ['OMAR']}],
#     'gender': 'male',
#     'birthDate': '1979-10-31'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/30',
#    'resource': {'resourceType': 'Patient',
#     'id': '30',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MAYRA <b>REICHENBACH </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>00fdac01-f3ab-4a6c-ac65-8cdc2db83814</td></tr><tr><td>Date of birth</td><td><span>15 August 1970</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '00fdac01-f3ab-4a6c-ac65-8cdc2db83814'}],
#     'active': False,
#     'name': [{'family': 'REICHENBACH', 'given': ['MAYRA']}],
#     'gender': 'female',
#     'birthDate': '1970-08-15'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/32',
#    'resource': {'resourceType': 'Patient',
#     'id': '32',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">HOBERT <b>COSWELL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>011ad234-9df9-40e9-91c1-80211b4a7bc8</td></tr><tr><td>Date of birth</td><td><span>27 October 1943</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}},
#        {'url': 'text', 'valueString': 'Asian'}]}],
#     'identifier': [{'value': '011ad234-9df9-40e9-91c1-80211b4a7bc8'}],
#     'active': False,
#     'name': [{'family': 'COSWELL', 'given': ['HOBERT']}],
#     'gender': 'male',
#     'birthDate': '1943-10-27'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/35',
#    'resource': {'resourceType': 'Patient',
#     'id': '35',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">SUK <b>HODEK </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>01304e75-3214-4ca9-8694-8884e85b2455</td></tr><tr><td>Date of birth</td><td><span>22 March 1960</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '01304e75-3214-4ca9-8694-8884e85b2455'}],
#     'active': False,
#     'name': [{'family': 'HODEK', 'given': ['SUK']}],
#     'gender': 'female',
#     'birthDate': '1960-03-22'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/36',
#    'resource': {'resourceType': 'Patient',
#     'id': '36',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">LILIAN <b>WHITMARSH </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>013ffde8-ac7d-4607-959c-66715d574c7c</td></tr><tr><td>Date of birth</td><td><span>21 October 1958</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '013ffde8-ac7d-4607-959c-66715d574c7c'}],
#     'active': False,
#     'name': [{'family': 'WHITMARSH', 'given': ['LILIAN']}],
#     'gender': 'female',
#     'birthDate': '1958-10-21'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/38',
#    'resource': {'resourceType': 'Patient',
#     'id': '38',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">SELENE <b>ARTUSO </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>015659e6-78b7-4afc-ba24-a537958bf2fb</td></tr><tr><td>Date of birth</td><td><span>09 February 1965</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '015659e6-78b7-4afc-ba24-a537958bf2fb'}],
#     'active': False,
#     'name': [{'family': 'ARTUSO', 'given': ['SELENE']}],
#     'gender': 'female',
#     'birthDate': '1965-02-09'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/40',
#    'resource': {'resourceType': 'Patient',
#     'id': '40',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MACK <b>KALAS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0164dcad-518f-4181-bf64-5d8e7b47a90c</td></tr><tr><td>Date of birth</td><td><span>05 December 1951</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0164dcad-518f-4181-bf64-5d8e7b47a90c'}],
#     'active': False,
#     'name': [{'family': 'KALAS', 'given': ['MACK']}],
#     'gender': 'male',
#     'birthDate': '1951-12-05'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/41',
#    'resource': {'resourceType': 'Patient',
#     'id': '41',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">JACKIE <b>HEVEY </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>01747c2b-c70e-4ce8-bf0c-fee20d3ba4a8</td></tr><tr><td>Date of birth</td><td><span>26 May 1973</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '01747c2b-c70e-4ce8-bf0c-fee20d3ba4a8'}],
#     'active': False,
#     'name': [{'family': 'HEVEY', 'given': ['JACKIE']}],
#     'gender': 'male',
#     'birthDate': '1973-05-26'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/42',
#    'resource': {'resourceType': 'Patient',
#     'id': '42',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">ETHELYN <b>CIPOLLONE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0177d2e0-98f5-4f3d-bcfd-497b7a07b3f8</td></tr><tr><td>Date of birth</td><td><span>02 November 1909</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0177d2e0-98f5-4f3d-bcfd-497b7a07b3f8'}],
#     'active': False,
#     'name': [{'family': 'CIPOLLONE', 'given': ['ETHELYN']}],
#     'gender': 'female',
#     'birthDate': '1909-11-02'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/43',
#    'resource': {'resourceType': 'Patient',
#     'id': '43',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MARINDA <b>GORENBERG </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>017b16a2-a179-42be-9380-4d5594015b5c</td></tr><tr><td>Date of birth</td><td><span>17 December 1956</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '017b16a2-a179-42be-9380-4d5594015b5c'}],
#     'active': False,
#     'name': [{'family': 'GORENBERG', 'given': ['MARINDA']}],
#     'gender': 'female',
#     'birthDate': '1956-12-17'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/49',
#    'resource': {'resourceType': 'Patient',
#     'id': '49',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">HAYWOOD <b>SHINGLEUR </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>01c99d51-f490-4fad-af2c-3f57025cbc29</td></tr><tr><td>Date of birth</td><td><span>04 November 1972</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '01c99d51-f490-4fad-af2c-3f57025cbc29'}],
#     'active': False,
#     'name': [{'family': 'SHINGLEUR', 'given': ['HAYWOOD']}],
#     'gender': 'male',
#     'birthDate': '1972-11-04'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/53',
#    'resource': {'resourceType': 'Patient',
#     'id': '53',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">CORDELL <b>MCGAFFEY </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02101f8b-9338-487e-a24f-0a5d9298c089</td></tr><tr><td>Date of birth</td><td><span>15 August 1962</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '02101f8b-9338-487e-a24f-0a5d9298c089'}],
#     'active': False,
#     'name': [{'family': 'MCGAFFEY', 'given': ['CORDELL']}],
#     'gender': 'male',
#     'birthDate': '1962-08-15'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/57',
#    'resource': {'resourceType': 'Patient',
#     'id': '57',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">BILLIE <b>GIGLER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>022bfb02-912a-44a4-a857-bc52290fbd94</td></tr><tr><td>Date of birth</td><td><span>19 June 1961</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '022bfb02-912a-44a4-a857-bc52290fbd94'}],
#     'active': False,
#     'name': [{'family': 'GIGLER', 'given': ['BILLIE']}],
#     'gender': 'male',
#     'birthDate': '1961-06-19'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/61',
#    'resource': {'resourceType': 'Patient',
#     'id': '61',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">EBONY <b>LOFGREN </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>026f7567-c1bc-4f54-995f-10b30dc211f4</td></tr><tr><td>Date of birth</td><td><span>21 January 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '026f7567-c1bc-4f54-995f-10b30dc211f4'}],
#     'active': False,
#     'name': [{'family': 'LOFGREN', 'given': ['EBONY']}],
#     'gender': 'female',
#     'birthDate': '1968-01-21'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/63',
#    'resource': {'resourceType': 'Patient',
#     'id': '63',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MITTIE <b>WONSER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>028aadd2-a214-4c7c-88a3-6aafefcd93f6</td></tr><tr><td>Date of birth</td><td><span>14 December 1955</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '028aadd2-a214-4c7c-88a3-6aafefcd93f6'}],
#     'active': False,
#     'name': [{'family': 'WONSER', 'given': ['MITTIE']}],
#     'gender': 'female',
#     'birthDate': '1955-12-14'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/64',
#    'resource': {'resourceType': 'Patient',
#     'id': '64',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">EVELYNN <b>BAHADUE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>028b1481-fd5b-4010-8b16-d0f57171950a</td></tr><tr><td>Date of birth</td><td><span>23 October 1974</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '028b1481-fd5b-4010-8b16-d0f57171950a'}],
#     'active': False,
#     'name': [{'family': 'BAHADUE', 'given': ['EVELYNN']}],
#     'gender': 'female',
#     'birthDate': '1974-10-23'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/65',
#    'resource': {'resourceType': 'Patient',
#     'id': '65',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">TRACEE <b>JACH </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02a3dad9-f9d5-42fb-8074-c16d45b4f5c8</td></tr><tr><td>Date of birth</td><td><span>31 March 1967</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '02a3dad9-f9d5-42fb-8074-c16d45b4f5c8'}],
#     'active': False,
#     'name': [{'family': 'JACH', 'given': ['TRACEE']}],
#     'gender': 'female',
#     'birthDate': '1967-03-31'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/66',
#    'resource': {'resourceType': 'Patient',
#     'id': '66',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">SHONDRA <b>ILLICH </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02aa6ff1-b19f-4794-9ece-a3e93129029c</td></tr><tr><td>Date of birth</td><td><span>27 June 1958</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '02aa6ff1-b19f-4794-9ece-a3e93129029c'}],
#     'active': False,
#     'name': [{'family': 'ILLICH', 'given': ['SHONDRA']}],
#     'gender': 'female',
#     'birthDate': '1958-06-27'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/67',
#    'resource': {'resourceType': 'Patient',
#     'id': '67',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">MCKINLEY <b>WEISSE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02ac2ac1-d4d6-4260-bda9-3b386a9d4163</td></tr><tr><td>Date of birth</td><td><span>18 October 1970</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '02ac2ac1-d4d6-4260-bda9-3b386a9d4163'}],
#     'active': False,
#     'name': [{'family': 'WEISSE', 'given': ['MCKINLEY']}],
#     'gender': 'male',
#     'birthDate': '1970-10-18'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/69',
#    'resource': {'resourceType': 'Patient',
#     'id': '69',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">CLEMENT <b>MINNING </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02b89823-8be1-4d2e-8233-95aca701c45d</td></tr><tr><td>Date of birth</td><td><span>27 October 1943</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}},
#        {'url': 'text', 'valueString': 'Asian'}]}],
#     'identifier': [{'value': '02b89823-8be1-4d2e-8233-95aca701c45d'}],
#     'active': False,
#     'name': [{'family': 'MINNING', 'given': ['CLEMENT']}],
#     'gender': 'male',
#     'birthDate': '1943-10-27'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/70',
#    'resource': {'resourceType': 'Patient',
#     'id': '70',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">NORBERT <b>KROESE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02c9e004-15eb-41f0-95c3-38e82af0b079</td></tr><tr><td>Date of birth</td><td><span>11 April 1948</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '02c9e004-15eb-41f0-95c3-38e82af0b079'}],
#     'active': False,
#     'name': [{'family': 'KROESE', 'given': ['NORBERT']}],
#     'gender': 'male',
#     'birthDate': '1948-04-11'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/72',
#    'resource': {'resourceType': 'Patient',
#     'id': '72',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">AZZIE <b>WILTS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02d4e2db-1544-455a-9b13-6751f8e65883</td></tr><tr><td>Date of birth</td><td><span>14 July 1947</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '02d4e2db-1544-455a-9b13-6751f8e65883'}],
#     'active': False,
#     'name': [{'family': 'WILTS', 'given': ['AZZIE']}],
#     'gender': 'female',
#     'birthDate': '1947-07-14'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/74',
#    'resource': {'resourceType': 'Patient',
#     'id': '74',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">DOMINQUE <b>MERNA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>02fbf1be-29b7-4da8-8bbd-14c7433f843f</td></tr><tr><td>Date of birth</td><td><span>05 January 1972</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '02fbf1be-29b7-4da8-8bbd-14c7433f843f'}],
#     'active': False,
#     'name': [{'family': 'MERNA', 'given': ['DOMINQUE']}],
#     'gender': 'female',
#     'birthDate': '1972-01-05'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/78',
#    'resource': {'resourceType': 'Patient',
#     'id': '78',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">BRADY <b>ZETTEL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0316bdaa-b4e1-40c4-9b7f-37791f787de0</td></tr><tr><td>Date of birth</td><td><span>05 January 1967</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0316bdaa-b4e1-40c4-9b7f-37791f787de0'}],
#     'active': False,
#     'name': [{'family': 'ZETTEL', 'given': ['BRADY']}],
#     'gender': 'male',
#     'birthDate': '1967-01-05'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/79',
#    'resource': {'resourceType': 'Patient',
#     'id': '79',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">LUISA <b>MCCOLLISTER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0317eeb0-791c-49aa-9e6f-8c2cacc5bd49</td></tr><tr><td>Date of birth</td><td><span>25 April 1946</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0317eeb0-791c-49aa-9e6f-8c2cacc5bd49'}],
#     'active': False,
#     'name': [{'family': 'MCCOLLISTER', 'given': ['LUISA']}],
#     'gender': 'female',
#     'birthDate': '1946-04-25'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/80',
#    'resource': {'resourceType': 'Patient',
#     'id': '80',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">RENALDO <b>FERDICO </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>031a9119-07af-4379-bb20-1b083372f664</td></tr><tr><td>Date of birth</td><td><span>09 November 1936</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '031a9119-07af-4379-bb20-1b083372f664'}],
#     'active': False,
#     'name': [{'family': 'FERDICO', 'given': ['RENALDO']}],
#     'gender': 'male',
#     'birthDate': '1936-11-09'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/81',
#    'resource': {'resourceType': 'Patient',
#     'id': '81',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">ORVAL <b>OR </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>03324a7e-e25d-4a11-9b1c-7df069daed9c</td></tr><tr><td>Date of birth</td><td><span>21 March 1956</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '03324a7e-e25d-4a11-9b1c-7df069daed9c'}],
#     'active': False,
#     'name': [{'family': 'OR', 'given': ['ORVAL']}],
#     'gender': 'male',
#     'birthDate': '1956-03-21'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/82',
#    'resource': {'resourceType': 'Patient',
#     'id': '82',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">CHRISTENE <b>CROUTHAMEL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0345d67f-6620-4cae-9c55-dfe6f3f38664</td></tr><tr><td>Date of birth</td><td><span>21 March 1961</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0345d67f-6620-4cae-9c55-dfe6f3f38664'}],
#     'active': False,
#     'name': [{'family': 'CROUTHAMEL', 'given': ['CHRISTENE']}],
#     'gender': 'female',
#     'birthDate': '1961-03-21'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/84',
#    'resource': {'resourceType': 'Patient',
#     'id': '84',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">HEIDY <b>BARENDS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>03509121-9c40-4245-b13f-181d5fdaafcc</td></tr><tr><td>Date of birth</td><td><span>14 March 1974</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '03509121-9c40-4245-b13f-181d5fdaafcc'}],
#     'active': False,
#     'name': [{'family': 'BARENDS', 'given': ['HEIDY']}],
# ...
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">JONIE <b>GATESY </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06ae6dc0-d5d6-46ea-bc77-58111d998aa9</td></tr><tr><td>Date of birth</td><td><span>22 November 1938</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '06ae6dc0-d5d6-46ea-bc77-58111d998aa9'}],
#     'active': False,
#     'name': [{'family': 'GATESY', 'given': ['JONIE']}],
#     'gender': 'female',
#     'birthDate': '1938-11-22'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/163',
#    'resource': {'resourceType': 'Patient',
#     'id': '163',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">JOHNNA <b>SARRETT </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06b3681d-fbd0-48e7-a06c-e32f128f48cc</td></tr><tr><td>Date of birth</td><td><span>28 June 1966</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '06b3681d-fbd0-48e7-a06c-e32f128f48cc'}],
#     'active': False,
#     'name': [{'family': 'SARRETT', 'given': ['JOHNNA']}],
#     'gender': 'female',
#     'birthDate': '1966-06-28'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/164',
#    'resource': {'resourceType': 'Patient',
#     'id': '164',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">EDWINA <b>BONA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06b54ac0-fb44-41fa-b8ce-6144ee676b00</td></tr><tr><td>Date of birth</td><td><span>03 January 1966</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}},
#        {'url': 'text', 'valueString': 'Black or African American'}]}],
#     'identifier': [{'value': '06b54ac0-fb44-41fa-b8ce-6144ee676b00'}],
#     'active': False,
#     'name': [{'family': 'BONA', 'given': ['EDWINA']}],
#     'gender': 'female',
#     'birthDate': '1966-01-03'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/165',
#    'resource': {'resourceType': 'Patient',
#     'id': '165',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">OBDULIA <b>KRY </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06b5d964-08e7-46c7-91ee-838d5256d904</td></tr><tr><td>Date of birth</td><td><span>12 June 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '06b5d964-08e7-46c7-91ee-838d5256d904'}],
#     'active': False,
#     'name': [{'family': 'KRY', 'given': ['OBDULIA']}],
#     'gender': 'female',
#     'birthDate': '1968-06-12'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/170',
#    'resource': {'resourceType': 'Patient',
#     'id': '170',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">KENYATTA <b>CRYDER </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06ec724a-de27-4cb7-bd12-1bd1489c7d05</td></tr><tr><td>Date of birth</td><td><span>04 February 1971</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '06ec724a-de27-4cb7-bd12-1bd1489c7d05'}],
#     'active': False,
#     'name': [{'family': 'CRYDER', 'given': ['KENYATTA']}],
#     'gender': 'female',
#     'birthDate': '1971-02-04'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/171',
#    'resource': {'resourceType': 'Patient',
#     'id': '171',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">ANIBAL <b>MORRAL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>06ed108a-05d4-472f-bd1b-122d6bcc3045</td></tr><tr><td>Date of birth</td><td><span>10 March 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '06ed108a-05d4-472f-bd1b-122d6bcc3045'}],
#     'active': False,
#     'name': [{'family': 'MORRAL', 'given': ['ANIBAL']}],
#     'gender': 'male',
#     'birthDate': '1968-03-10'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/173',
#    'resource': {'resourceType': 'Patient',
#     'id': '173',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">RORY <b>PUTNAL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0703051a-4b41-458d-a1c1-7d284c958356</td></tr><tr><td>Date of birth</td><td><span>24 March 1968</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0703051a-4b41-458d-a1c1-7d284c958356'}],
#     'active': False,
#     'name': [{'family': 'PUTNAL', 'given': ['RORY']}],
#     'gender': 'male',
#     'birthDate': '1968-03-24'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/176',
#    'resource': {'resourceType': 'Patient',
#     'id': '176',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">ELMER <b>JASMIN </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>071dae97-e378-4ac0-ba3b-1fb6aae3a012</td></tr><tr><td>Date of birth</td><td><span>25 November 1964</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '071dae97-e378-4ac0-ba3b-1fb6aae3a012'}],
#     'active': False,
#     'name': [{'family': 'JASMIN', 'given': ['ELMER']}],
#     'gender': 'male',
#     'birthDate': '1964-11-25'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/177',
#    'resource': {'resourceType': 'Patient',
#     'id': '177',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">TOMASA <b>MAIETTA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0729671d-4b9e-4d3b-957a-7c4024fa29e7</td></tr><tr><td>Date of birth</td><td><span>25 April 1966</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}},
#        {'url': 'text', 'valueString': 'Hispanic or Latino'}]}],
#     'identifier': [{'value': '0729671d-4b9e-4d3b-957a-7c4024fa29e7'}],
#     'active': False,
#     'name': [{'family': 'MAIETTA', 'given': ['TOMASA']}],
#     'gender': 'female',
#     'birthDate': '1966-04-25'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/180',
#    'resource': {'resourceType': 'Patient',
#     'id': '180',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">VINA <b>ACE </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0745e4d2-10e6-44a6-9f3c-debf4addc208</td></tr><tr><td>Date of birth</td><td><span>21 April 1977</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0745e4d2-10e6-44a6-9f3c-debf4addc208'}],
#     'active': False,
#     'name': [{'family': 'ACE', 'given': ['VINA']}],
#     'gender': 'female',
#     'birthDate': '1977-04-21'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/181',
#    'resource': {'resourceType': 'Patient',
#     'id': '181',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">BRITNEY <b>MINNS </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>075cbb91-fb3b-45ba-be65-23f227afbe38</td></tr><tr><td>Date of birth</td><td><span>16 September 1973</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '075cbb91-fb3b-45ba-be65-23f227afbe38'}],
#     'active': False,
#     'name': [{'family': 'MINNS', 'given': ['BRITNEY']}],
#     'gender': 'female',
#     'birthDate': '1973-09-16'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/182',
#    'resource': {'resourceType': 'Patient',
#     'id': '182',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">WILL <b>VILANOVA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>0768ad1e-1969-4b40-a5ab-724760134faa</td></tr><tr><td>Date of birth</td><td><span>10 September 1950</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '0768ad1e-1969-4b40-a5ab-724760134faa'}],
#     'active': False,
#     'name': [{'family': 'VILANOVA', 'given': ['WILL']}],
#     'gender': 'male',
#     'birthDate': '1950-09-10'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/183',
#    'resource': {'resourceType': 'Patient',
#     'id': '183',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">FERDINAND <b>NORSKOG </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>076bbf0d-ab79-4ddd-84da-ab874307314d</td></tr><tr><td>Date of birth</td><td><span>24 October 1974</span></td></tr></tbody></table></div>'},
#     'identifier': [{'value': '076bbf0d-ab79-4ddd-84da-ab874307314d'}],
#     'active': False,
#     'name': [{'family': 'NORSKOG', 'given': ['FERDINAND']}],
#     'gender': 'male',
#     'birthDate': '1974-10-24'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/184',
#    'resource': {'resourceType': 'Patient',
#     'id': '184',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">LASONYA <b>VOGELZANG </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>077edadc-4a80-4a43-b6d1-e7539dd6f1d9</td></tr><tr><td>Date of birth</td><td><span>28 January 1946</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '077edadc-4a80-4a43-b6d1-e7539dd6f1d9'}],
#     'active': False,
#     'name': [{'family': 'VOGELZANG', 'given': ['LASONYA']}],
#     'gender': 'female',
#     'birthDate': '1946-01-28'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:8081/fhir/Patient/185',
#    'resource': {'resourceType': 'Patient',
#     'id': '185',
#     'meta': {'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-patient']},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">DREW <b>POPIEL </b></div><table class="hapiPropertyTable"><tbody><tr><td>Identifier</td><td>078d48f8-e9f3-467a-82f3-409c909ead14</td></tr><tr><td>Date of birth</td><td><span>12 May 1946</span></td></tr></tbody></table></div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}},
#        {'url': 'text', 'valueString': 'White'}]}],
#     'identifier': [{'value': '078d48f8-e9f3-467a-82f3-409c909ead14'}],
#     'active': False,
#     'name': [{'family': 'POPIEL', 'given': ['DREW']}],
#     'gender': 'male',
#     'birthDate': '1946-05-12'}}]}

# %%
FHIR_SERVER="http://pwebmedcit.services.brown.edu:8081/fhir"
r = s.get(f"{FHIR_SERVER}/metadata")
print(f"HTTP Status Code: {r.status_code}")
capability_statement = r.json()
# Out:
# HTTP Status Code: 200

# %%
print(f"FHIR Version Supported: {capability_statement['fhirVersion']}")
print(f"Formats Supported: {', '.join(capability_statement['format'])}")
print()

print(f"Number of RESTful Endpoints: {len(capability_statement['rest'])}")
for rest in capability_statement['rest']:
    print(f"Endpoint Type: {rest['mode']}")
# Out:
# FHIR Version Supported: 4.0.1
# Formats Supported: application/fhir+xml, xml, application/fhir+json, json, html/json, html/xml
#
# Number of RESTful Endpoints: 1
# Endpoint Type: server

# %%
# r = s.get(f"{FHIR_SERVER}/Patient")
m = s.get(f"http://pwebmedcit.services.brown.edu:8081/fhir/Patient?patient={patient_id}", headers = {'Accept': 'application/fhir/json'}, auth=credentials) 
patient_bundle = m.json()
print(f"Resource Type: {patient_bundle['resourceType']}")
print(f"Bundle Type: {patient_bundle['type']}")

# Create list of just the Patient Resources in the Bundle
patients = [entry['resource'] for entry in patient_bundle['entry']]
# Out:
# Resource Type: Bundle
# Bundle Type: searchset

# %%
print(f"Number of matches: {patient_bundle['total']}")
print(f"Number of Patients included in Bundle: {len(patient_bundle['entry'])}")
# Out:
# Number of matches: 2694
# Number of Patients included in Bundle: 100
